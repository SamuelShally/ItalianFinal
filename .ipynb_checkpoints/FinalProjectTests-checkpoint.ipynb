# %% [markdown]
#  **Data for a single month and year:**

# %%
import requests
import json

api_key = 'Kv2FxshEyzdodl0Hh00O0OaHd0wASYm6'
base_url = 'https://api.nytimes.com/svc/archive/v1/1919/1.json'

# Make the API request
url = f'{base_url}?api-key={api_key}'
response = requests.get(url)

keywords = ['anarchist', 'anarchists', 'anarchism', 'anarchy']
collection = [] 

# Check if the request was successful (status code 200)
if response.status_code == 200:
    # Parse the JSON response
    data = response.json()

    # print(data)
  
    for artical in data['response']['docs']:
        headline = artical['headline']['main'].lower()
        
        found = False
        for word in keywords:
            if word in headline:
                found = True
                collection.append(artical)
                break
    
else:
    print(f"Error: {response.status_code}, {response.text}")

count = 1
for artical in collection: 
    headline = artical['headline']['main']
    date = artical['pub_date']
    print(f"{count}: {date} {headline}\n")
    count += 1 

# print(collection)
# Out:
# 1: 1919-01-08T05:00:00+0000 JAPAN SAW FRIEND IN COL. ROOSEVELT; Baron Makino, on Eve of Sailing for Peace Parley, PaysWarm Tribute.HELPED END FORMER WAR Both in Russian Negotiations and Califonnia Dispute, Speaker Recalls Great Services SPANISH-AMERICAN TRIBUTE. "America's Most Beloved Citizen," La Prensa Calls Colonel. NEW YORKERS DO HOMAGE. See in Roosevelt's Death a Loss to All High Activities. MOVED BY RUSSIAN ANARCHY. Roosevelt, in Last Message, Hoped for a Genuine Republic.
#
# 2: 1919-01-08T05:00:00+0000 BOLSHEVISM GAINS ALL OVER POLAND; Waiters, Janitors, and Domestics in Warsaw Lord itOver Employers.ANARCHY IN OTHER CITIESAgitators Tell People That if Allies Come They Will Act asDid the Germans. POLES ADVANCE ON THORN. Will Only Let Germans from Ukraine Pass Through Poland if Disarmed.
#
# 3: 1919-01-08T05:00:00+0000 RUSSIAN REDS INCITE ANARCHY IN BERLIN; Government Made Preparations to Storm the Headquarters of the Police Force.
#
# 4: 1919-01-09T05:00:00+0000 SUGGEST LIFTING BLOCKADE; Americans Favor It as a Means of Averting German Anarchy. FRENCH SHOW OPPOSITION But Our Delegates' View Has Full Backing of President Wilson's Influence. UNIVERSAL MENACE SEEN President and Colleagues Fear the Spread of Bolshevism to the West and South. SUGGEST LIFTING BLOCKADE
#
# 5: 1919-01-10T05:00:00+0000 ANARCHY IN BERLIN.
#
# 6: 1919-01-12T05:00:00+0000 LEAGUE OF NATIONS TO AVERT INTERNATIONAL ANARCHY; Collective Instead of Individual Nationalism, Patterned After the Union of American States, Advocated as a Solution of Post-War Problems DIPLOMACY A "FLIM-FLAM." INTERNATIONAL ANARCHY. AMERICA'S EXAMPLE. BIRTH OF OUR CONSTITUTION. "WORLD CONSTITUTION" NEEDED
#
# 7: 1919-01-15T05:00:00+0000 MAZE OF PEACE PROPOSALS; Fear Expressed That They May Prevent Early Allied Decisions. CRISIS MAY FORCE ACTION Some Hope Seen in Recognition of Instant Necessity of Checking Anarchy. DEADLOCK ON POLAND British Evidently in Accord with Americans in Opposing Sending Troops Thither. Conference Attempted Too Much. MAZE OF PEACE PROPOSALS German Ships Wanted for Troops. French Favor Force in Russia.
#
# 8: 1919-01-22T05:00:00+0000 BERKMAN SPONSOR FOR TROTZKY HERE; Emma Goldman Also One of His Closest Associates, Tunney Tells Senators.12,000 REDS IN NEW YORKFormer Police Inspector DisclosesAnarchist Plot to Blow UpRockefeller Family. Trotsky's Purpose Made Plain. 12,000 Anarchists Here.
#
# 9: 1919-01-23T05:00:00+0000 BERLIN DEPLORES CHOICE OF WEIMAR FOR CONVENTION; Danger of Outbreaks Asserted if Cabinet Is Absent Long at Assembly. FEAR SHIFT OF CAPITAL Intention to Change Denied-- Aim to Escape the Prussian Spirit. EBERT WINS 132 SEATS Coalition with Democrats Would Control--Provisional Government to be Elected. Fears New Anarchy in Berlin. Measures to Guard East Front. BERLIN DEPLORES CHOICE OF WEIMAR
#
# 10: 1919-01-24T05:00:00+0000 RIDDER NEWSPAPER UNDER NEW INQUIRY; Staats-Zeitung Editorial Cited to Senators as Sample of German Propaganda. ANARCHIST SCHOOLS GROW Senator Overman Discusses Restricting Immigration to AngloSaxons for Ten Years. Germans Afraid to Come Here. How Paper Was Financed.
#
# 11: 1919-01-28T05:00:00+0000 MANIAC KILLS THREE MEN IN PHILADELPHIA; Overpowered After a Running Fight--German Anarchistic Tracts Found in His Room.

# %% [markdown]
# ### **Data for multi-year timeframe**

# %%
### import requests
import json

api_key = 'Kv2FxshEyzdodl0Hh00O0OaHd0wASYm6'
base_url = 'https://api.nytimes.com/svc/archive/v1/'

start = 1890
end = 1891

keywords = ['anarchist', 'anarchists', 'anarchism']
collection = [] 

url_template = f'{base_url}{start}/%d.json?api-key={api_key}'

for year in range(start, end + 1):
    for month in range(1, 2):
    
        url = url_template % month
        response = requests.get(url)
        
        # Check if the request was successful (status code 200)
        if response.status_code == 200:
            # Parse the JSON response
            data = response.json()
          
            for artical in data['response']['docs']:
                headline = artical['headline']['main'].lower()
                
                found = False
                for word in keywords:
                    if word in headline:
                        found = True
                        collection.append(artical)
                        break
            
        else:
            print(f"Error: {response.status_code}, {response.text}")

count = 1
for artical in collection: 
    headline = artical['headline']['main']
    date = artical['pub_date']
    print(f"{count}: {date} {headline}\n")
    count += 1 

# print(collection)
# Out:
# 1: 1890-01-05T05:00:00+0000 HIS THREATS CARRIED OUT.; A CRAZY ANARCHIST KILLS HIS WIFE, HIS CHILD, AND HIMSELF.
#
# 2: 1890-01-05T05:00:00+0000 HIS THREATS CARRIED OUT.; A CRAZY ANARCHIST KILLS HIS WIFE, HIS CHILD, AND HIMSELF.

# %% [markdown]
# ### Writing data to the file.

# %%
import requests
import json
import csv
import time

api_key = 'Kv2FxshEyzdodl0Hh00O0OaHd0wASYm6'
base_url = 'https://api.nytimes.com/svc/archive/v1/'

start = 1890
end = 1890

keywords = ['anarchist', 'anarchists', 'anarchism']
collection = [] 

url_template = f'{base_url}{start}/%d.json?api-key={api_key}'

print("Program is running...")

for year in range(start, end + 1):
    for month in range(1, 13):  # Fetch for all 12 months
    
        url = url_template % month
        response = requests.get(url)
        
        # Check if the request was successful (status code 200)
        if response.status_code == 200:
            # Parse the JSON response
            data = response.json()
          
            for article in data['response']['docs']:
                headline = article['headline']['main'].lower()
                
                found = any(word in headline for word in keywords)
                if found:
                    collection.append(article)
                    
            time.sleep(13)  # Sleep for 13 seconds to avoid rate limits
        
        else:
            print(f"Error: {response.status_code}, {response.text}")

# Write data to CSV file
csv_file_path = 'nyt_headlines.csv'
fieldnames = ['publish_date', 'headline']

with open(csv_file_path, 'a', newline='', encoding='utf-8') as csvfile:
    writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
    
    # Write header only if the file is empty
    if csvfile.tell() == 0:
        writer.writeheader()
    
    for article in collection:
        publish_date = article['pub_date']
        headline = article['headline']['main']
        writer.writerow({'publish_date': publish_date, 'headline': headline})

print("Program is done. Data written to nyt_headlines.csv.")
# Out:
# Program is running...
# Program is done. Data written to nyt_headlines.csv.

# %%
import requests
import json
import csv
import time

api_key = 'Kv2FxshEyzdodl0Hh00O0OaHd0wASYm6'
base_url = 'https://api.nytimes.com/svc/archive/v1/'

start = 1911
end = 1920

keywords = ['anarchist', 'anarchists', 'anarchism']
collection = [] 

url_template = f'{base_url}%d/%d.json?api-key={api_key}'

print("Program is running...")

for year in range(start, end + 1):
    for month in range(1, 13):  # Fetch for all 12 months
        full_url = url_template % (year, month)
        print(full_url)
            
        response = requests.get(full_url)
        
        # Check if the request was successful (status code 200)
        if response.status_code == 200:
            # Parse the JSON response
            data = response.json()
          
            for article in data['response']['docs']:
                headline = article['headline']['main'].lower()
                
                found = any(word in headline for word in keywords)
                if found:
                    collection.append(article)
                    
            time.sleep(13)  # Sleep for 13 seconds to avoid rate limits
        
        else:
            print(f"Error: {response.status_code}, {response.text}")

# Write data to CSV file
csv_file_path = 'nyt_headlines.csv'
fieldnames = ['publish_date', 'headline']

with open(csv_file_path, 'a', newline='', encoding='utf-8') as csvfile:
    writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
    
    # Write header only if the file is empty
    if csvfile.tell() == 0:
        writer.writeheader()
    
    for article in collection:
        publish_date = article['pub_date']
        headline = article['headline']['main']
        writer.writerow({'publish_date': publish_date, 'headline': headline})

print("Program is done. Data written to nyt_headlines.csv.")
# Out:
# Program is running...
# https://api.nytimes.com/svc/archive/v1/1911/1.json?api-key=Kv2FxshEyzdodl0Hh00O0OaHd0wASYm6
# https://api.nytimes.com/svc/archive/v1/1911/2.json?api-key=Kv2FxshEyzdodl0Hh00O0OaHd0wASYm6
# https://api.nytimes.com/svc/archive/v1/1911/3.json?api-key=Kv2FxshEyzdodl0Hh00O0OaHd0wASYm6
# https://api.nytimes.com/svc/archive/v1/1911/4.json?api-key=Kv2FxshEyzdodl0Hh00O0OaHd0wASYm6
# https://api.nytimes.com/svc/archive/v1/1911/5.json?api-key=Kv2FxshEyzdodl0Hh00O0OaHd0wASYm6
# https://api.nytimes.com/svc/archive/v1/1911/6.json?api-key=Kv2FxshEyzdodl0Hh00O0OaHd0wASYm6
# https://api.nytimes.com/svc/archive/v1/1911/7.json?api-key=Kv2FxshEyzdodl0Hh00O0OaHd0wASYm6
# https://api.nytimes.com/svc/archive/v1/1911/8.json?api-key=Kv2FxshEyzdodl0Hh00O0OaHd0wASYm6
# https://api.nytimes.com/svc/archive/v1/1911/9.json?api-key=Kv2FxshEyzdodl0Hh00O0OaHd0wASYm6
# https://api.nytimes.com/svc/archive/v1/1911/10.json?api-key=Kv2FxshEyzdodl0Hh00O0OaHd0wASYm6
# https://api.nytimes.com/svc/archive/v1/1911/11.json?api-key=Kv2FxshEyzdodl0Hh00O0OaHd0wASYm6
# https://api.nytimes.com/svc/archive/v1/1911/12.json?api-key=Kv2FxshEyzdodl0Hh00O0OaHd0wASYm6
# https://api.nytimes.com/svc/archive/v1/1912/1.json?api-key=Kv2FxshEyzdodl0Hh00O0OaHd0wASYm6
# https://api.nytimes.com/svc/archive/v1/1912/2.json?api-key=Kv2FxshEyzdodl0Hh00O0OaHd0wASYm6
# https://api.nytimes.com/svc/archive/v1/1912/3.json?api-key=Kv2FxshEyzdodl0Hh00O0OaHd0wASYm6
# https://api.nytimes.com/svc/archive/v1/1912/4.json?api-key=Kv2FxshEyzdodl0Hh00O0OaHd0wASYm6
# https://api.nytimes.com/svc/archive/v1/1912/5.json?api-key=Kv2FxshEyzdodl0Hh00O0OaHd0wASYm6
# https://api.nytimes.com/svc/archive/v1/1912/6.json?api-key=Kv2FxshEyzdodl0Hh00O0OaHd0wASYm6
# https://api.nytimes.com/svc/archive/v1/1912/7.json?api-key=Kv2FxshEyzdodl0Hh00O0OaHd0wASYm6
# https://api.nytimes.com/svc/archive/v1/1912/8.json?api-key=Kv2FxshEyzdodl0Hh00O0OaHd0wASYm6
# https://api.nytimes.com/svc/archive/v1/1912/9.json?api-key=Kv2FxshEyzdodl0Hh00O0OaHd0wASYm6
# https://api.nytimes.com/svc/archive/v1/1912/10.json?api-key=Kv2FxshEyzdodl0Hh00O0OaHd0wASYm6
# https://api.nytimes.com/svc/archive/v1/1912/11.json?api-key=Kv2FxshEyzdodl0Hh00O0OaHd0wASYm6
# https://api.nytimes.com/svc/archive/v1/1912/12.json?api-key=Kv2FxshEyzdodl0Hh00O0OaHd0wASYm6
# https://api.nytimes.com/svc/archive/v1/1913/1.json?api-key=Kv2FxshEyzdodl0Hh00O0OaHd0wASYm6
# https://api.nytimes.com/svc/archive/v1/1913/2.json?api-key=Kv2FxshEyzdodl0Hh00O0OaHd0wASYm6
# https://api.nytimes.com/svc/archive/v1/1913/3.json?api-key=Kv2FxshEyzdodl0Hh00O0OaHd0wASYm6
# https://api.nytimes.com/svc/archive/v1/1913/4.json?api-key=Kv2FxshEyzdodl0Hh00O0OaHd0wASYm6
# https://api.nytimes.com/svc/archive/v1/1913/5.json?api-key=Kv2FxshEyzdodl0Hh00O0OaHd0wASYm6
# https://api.nytimes.com/svc/archive/v1/1913/6.json?api-key=Kv2FxshEyzdodl0Hh00O0OaHd0wASYm6
# https://api.nytimes.com/svc/archive/v1/1913/7.json?api-key=Kv2FxshEyzdodl0Hh00O0OaHd0wASYm6
# https://api.nytimes.com/svc/archive/v1/1913/8.json?api-key=Kv2FxshEyzdodl0Hh00O0OaHd0wASYm6
# https://api.nytimes.com/svc/archive/v1/1913/9.json?api-key=Kv2FxshEyzdodl0Hh00O0OaHd0wASYm6
# https://api.nytimes.com/svc/archive/v1/1913/10.json?api-key=Kv2FxshEyzdodl0Hh00O0OaHd0wASYm6
# https://api.nytimes.com/svc/archive/v1/1913/11.json?api-key=Kv2FxshEyzdodl0Hh00O0OaHd0wASYm6
# https://api.nytimes.com/svc/archive/v1/1913/12.json?api-key=Kv2FxshEyzdodl0Hh00O0OaHd0wASYm6
# https://api.nytimes.com/svc/archive/v1/1914/1.json?api-key=Kv2FxshEyzdodl0Hh00O0OaHd0wASYm6
# https://api.nytimes.com/svc/archive/v1/1914/2.json?api-key=Kv2FxshEyzdodl0Hh00O0OaHd0wASYm6
# https://api.nytimes.com/svc/archive/v1/1914/3.json?api-key=Kv2FxshEyzdodl0Hh00O0OaHd0wASYm6
# https://api.nytimes.com/svc/archive/v1/1914/4.json?api-key=Kv2FxshEyzdodl0Hh00O0OaHd0wASYm6
# https://api.nytimes.com/svc/archive/v1/1914/5.json?api-key=Kv2FxshEyzdodl0Hh00O0OaHd0wASYm6
# https://api.nytimes.com/svc/archive/v1/1914/6.json?api-key=Kv2FxshEyzdodl0Hh00O0OaHd0wASYm6
# https://api.nytimes.com/svc/archive/v1/1914/7.json?api-key=Kv2FxshEyzdodl0Hh00O0OaHd0wASYm6
# https://api.nytimes.com/svc/archive/v1/1914/8.json?api-key=Kv2FxshEyzdodl0Hh00O0OaHd0wASYm6
# https://api.nytimes.com/svc/archive/v1/1914/9.json?api-key=Kv2FxshEyzdodl0Hh00O0OaHd0wASYm6
# https://api.nytimes.com/svc/archive/v1/1914/10.json?api-key=Kv2FxshEyzdodl0Hh00O0OaHd0wASYm6
# https://api.nytimes.com/svc/archive/v1/1914/11.json?api-key=Kv2FxshEyzdodl0Hh00O0OaHd0wASYm6
# https://api.nytimes.com/svc/archive/v1/1914/12.json?api-key=Kv2FxshEyzdodl0Hh00O0OaHd0wASYm6
# https://api.nytimes.com/svc/archive/v1/1915/1.json?api-key=Kv2FxshEyzdodl0Hh00O0OaHd0wASYm6
# https://api.nytimes.com/svc/archive/v1/1915/2.json?api-key=Kv2FxshEyzdodl0Hh00O0OaHd0wASYm6
# https://api.nytimes.com/svc/archive/v1/1915/3.json?api-key=Kv2FxshEyzdodl0Hh00O0OaHd0wASYm6
# https://api.nytimes.com/svc/archive/v1/1915/4.json?api-key=Kv2FxshEyzdodl0Hh00O0OaHd0wASYm6
# https://api.nytimes.com/svc/archive/v1/1915/5.json?api-key=Kv2FxshEyzdodl0Hh00O0OaHd0wASYm6
# https://api.nytimes.com/svc/archive/v1/1915/6.json?api-key=Kv2FxshEyzdodl0Hh00O0OaHd0wASYm6
# https://api.nytimes.com/svc/archive/v1/1915/7.json?api-key=Kv2FxshEyzdodl0Hh00O0OaHd0wASYm6
# https://api.nytimes.com/svc/archive/v1/1915/8.json?api-key=Kv2FxshEyzdodl0Hh00O0OaHd0wASYm6
# https://api.nytimes.com/svc/archive/v1/1915/9.json?api-key=Kv2FxshEyzdodl0Hh00O0OaHd0wASYm6
# https://api.nytimes.com/svc/archive/v1/1915/10.json?api-key=Kv2FxshEyzdodl0Hh00O0OaHd0wASYm6
# https://api.nytimes.com/svc/archive/v1/1915/11.json?api-key=Kv2FxshEyzdodl0Hh00O0OaHd0wASYm6
# https://api.nytimes.com/svc/archive/v1/1915/12.json?api-key=Kv2FxshEyzdodl0Hh00O0OaHd0wASYm6
# https://api.nytimes.com/svc/archive/v1/1916/1.json?api-key=Kv2FxshEyzdodl0Hh00O0OaHd0wASYm6
# https://api.nytimes.com/svc/archive/v1/1916/2.json?api-key=Kv2FxshEyzdodl0Hh00O0OaHd0wASYm6
# https://api.nytimes.com/svc/archive/v1/1916/3.json?api-key=Kv2FxshEyzdodl0Hh00O0OaHd0wASYm6
# https://api.nytimes.com/svc/archive/v1/1916/4.json?api-key=Kv2FxshEyzdodl0Hh00O0OaHd0wASYm6
# https://api.nytimes.com/svc/archive/v1/1916/5.json?api-key=Kv2FxshEyzdodl0Hh00O0OaHd0wASYm6
# https://api.nytimes.com/svc/archive/v1/1916/6.json?api-key=Kv2FxshEyzdodl0Hh00O0OaHd0wASYm6
# https://api.nytimes.com/svc/archive/v1/1916/7.json?api-key=Kv2FxshEyzdodl0Hh00O0OaHd0wASYm6
# https://api.nytimes.com/svc/archive/v1/1916/8.json?api-key=Kv2FxshEyzdodl0Hh00O0OaHd0wASYm6
# https://api.nytimes.com/svc/archive/v1/1916/9.json?api-key=Kv2FxshEyzdodl0Hh00O0OaHd0wASYm6
# https://api.nytimes.com/svc/archive/v1/1916/10.json?api-key=Kv2FxshEyzdodl0Hh00O0OaHd0wASYm6
# https://api.nytimes.com/svc/archive/v1/1916/11.json?api-key=Kv2FxshEyzdodl0Hh00O0OaHd0wASYm6
# https://api.nytimes.com/svc/archive/v1/1916/12.json?api-key=Kv2FxshEyzdodl0Hh00O0OaHd0wASYm6
# https://api.nytimes.com/svc/archive/v1/1917/1.json?api-key=Kv2FxshEyzdodl0Hh00O0OaHd0wASYm6
# https://api.nytimes.com/svc/archive/v1/1917/2.json?api-key=Kv2FxshEyzdodl0Hh00O0OaHd0wASYm6
# https://api.nytimes.com/svc/archive/v1/1917/3.json?api-key=Kv2FxshEyzdodl0Hh00O0OaHd0wASYm6
# https://api.nytimes.com/svc/archive/v1/1917/4.json?api-key=Kv2FxshEyzdodl0Hh00O0OaHd0wASYm6
# https://api.nytimes.com/svc/archive/v1/1917/5.json?api-key=Kv2FxshEyzdodl0Hh00O0OaHd0wASYm6
# https://api.nytimes.com/svc/archive/v1/1917/6.json?api-key=Kv2FxshEyzdodl0Hh00O0OaHd0wASYm6
# https://api.nytimes.com/svc/archive/v1/1917/7.json?api-key=Kv2FxshEyzdodl0Hh00O0OaHd0wASYm6
# https://api.nytimes.com/svc/archive/v1/1917/8.json?api-key=Kv2FxshEyzdodl0Hh00O0OaHd0wASYm6
# https://api.nytimes.com/svc/archive/v1/1917/9.json?api-key=Kv2FxshEyzdodl0Hh00O0OaHd0wASYm6
# https://api.nytimes.com/svc/archive/v1/1917/10.json?api-key=Kv2FxshEyzdodl0Hh00O0OaHd0wASYm6
# https://api.nytimes.com/svc/archive/v1/1917/11.json?api-key=Kv2FxshEyzdodl0Hh00O0OaHd0wASYm6
# https://api.nytimes.com/svc/archive/v1/1917/12.json?api-key=Kv2FxshEyzdodl0Hh00O0OaHd0wASYm6
# https://api.nytimes.com/svc/archive/v1/1918/1.json?api-key=Kv2FxshEyzdodl0Hh00O0OaHd0wASYm6
# https://api.nytimes.com/svc/archive/v1/1918/2.json?api-key=Kv2FxshEyzdodl0Hh00O0OaHd0wASYm6
# https://api.nytimes.com/svc/archive/v1/1918/3.json?api-key=Kv2FxshEyzdodl0Hh00O0OaHd0wASYm6
# https://api.nytimes.com/svc/archive/v1/1918/4.json?api-key=Kv2FxshEyzdodl0Hh00O0OaHd0wASYm6
# https://api.nytimes.com/svc/archive/v1/1918/5.json?api-key=Kv2FxshEyzdodl0Hh00O0OaHd0wASYm6
# https://api.nytimes.com/svc/archive/v1/1918/6.json?api-key=Kv2FxshEyzdodl0Hh00O0OaHd0wASYm6
# https://api.nytimes.com/svc/archive/v1/1918/7.json?api-key=Kv2FxshEyzdodl0Hh00O0OaHd0wASYm6
# https://api.nytimes.com/svc/archive/v1/1918/8.json?api-key=Kv2FxshEyzdodl0Hh00O0OaHd0wASYm6
# https://api.nytimes.com/svc/archive/v1/1918/9.json?api-key=Kv2FxshEyzdodl0Hh00O0OaHd0wASYm6
# https://api.nytimes.com/svc/archive/v1/1918/10.json?api-key=Kv2FxshEyzdodl0Hh00O0OaHd0wASYm6
# https://api.nytimes.com/svc/archive/v1/1918/11.json?api-key=Kv2FxshEyzdodl0Hh00O0OaHd0wASYm6
# https://api.nytimes.com/svc/archive/v1/1918/12.json?api-key=Kv2FxshEyzdodl0Hh00O0OaHd0wASYm6
# https://api.nytimes.com/svc/archive/v1/1919/1.json?api-key=Kv2FxshEyzdodl0Hh00O0OaHd0wASYm6
# https://api.nytimes.com/svc/archive/v1/1919/2.json?api-key=Kv2FxshEyzdodl0Hh00O0OaHd0wASYm6
# https://api.nytimes.com/svc/archive/v1/1919/3.json?api-key=Kv2FxshEyzdodl0Hh00O0OaHd0wASYm6
# https://api.nytimes.com/svc/archive/v1/1919/4.json?api-key=Kv2FxshEyzdodl0Hh00O0OaHd0wASYm6
# https://api.nytimes.com/svc/archive/v1/1919/5.json?api-key=Kv2FxshEyzdodl0Hh00O0OaHd0wASYm6
# https://api.nytimes.com/svc/archive/v1/1919/6.json?api-key=Kv2FxshEyzdodl0Hh00O0OaHd0wASYm6
# https://api.nytimes.com/svc/archive/v1/1919/7.json?api-key=Kv2FxshEyzdodl0Hh00O0OaHd0wASYm6
# https://api.nytimes.com/svc/archive/v1/1919/8.json?api-key=Kv2FxshEyzdodl0Hh00O0OaHd0wASYm6
# https://api.nytimes.com/svc/archive/v1/1919/9.json?api-key=Kv2FxshEyzdodl0Hh00O0OaHd0wASYm6
# https://api.nytimes.com/svc/archive/v1/1919/10.json?api-key=Kv2FxshEyzdodl0Hh00O0OaHd0wASYm6
# https://api.nytimes.com/svc/archive/v1/1919/11.json?api-key=Kv2FxshEyzdodl0Hh00O0OaHd0wASYm6
# https://api.nytimes.com/svc/archive/v1/1919/12.json?api-key=Kv2FxshEyzdodl0Hh00O0OaHd0wASYm6
# https://api.nytimes.com/svc/archive/v1/1920/1.json?api-key=Kv2FxshEyzdodl0Hh00O0OaHd0wASYm6
# https://api.nytimes.com/svc/archive/v1/1920/2.json?api-key=Kv2FxshEyzdodl0Hh00O0OaHd0wASYm6
# https://api.nytimes.com/svc/archive/v1/1920/3.json?api-key=Kv2FxshEyzdodl0Hh00O0OaHd0wASYm6
# https://api.nytimes.com/svc/archive/v1/1920/4.json?api-key=Kv2FxshEyzdodl0Hh00O0OaHd0wASYm6
# https://api.nytimes.com/svc/archive/v1/1920/5.json?api-key=Kv2FxshEyzdodl0Hh00O0OaHd0wASYm6
# https://api.nytimes.com/svc/archive/v1/1920/6.json?api-key=Kv2FxshEyzdodl0Hh00O0OaHd0wASYm6
# https://api.nytimes.com/svc/archive/v1/1920/7.json?api-key=Kv2FxshEyzdodl0Hh00O0OaHd0wASYm6
# https://api.nytimes.com/svc/archive/v1/1920/8.json?api-key=Kv2FxshEyzdodl0Hh00O0OaHd0wASYm6
# https://api.nytimes.com/svc/archive/v1/1920/9.json?api-key=Kv2FxshEyzdodl0Hh00O0OaHd0wASYm6
# https://api.nytimes.com/svc/archive/v1/1920/10.json?api-key=Kv2FxshEyzdodl0Hh00O0OaHd0wASYm6
# https://api.nytimes.com/svc/archive/v1/1920/11.json?api-key=Kv2FxshEyzdodl0Hh00O0OaHd0wASYm6
# https://api.nytimes.com/svc/archive/v1/1920/12.json?api-key=Kv2FxshEyzdodl0Hh00O0OaHd0wASYm6
# Program is done. Data written to nyt_headlines.csv.

# %%
import csv
from datetime import datetime
from collections import Counter
import matplotlib.pyplot as plt

# Read data from CSV file
csv_file_path = 'nyt_headlines.csv'
fieldnames = ['publish_date', 'headline']
collection = []

with open(csv_file_path, 'r', encoding='utf-8') as csvfile:
    reader = csv.DictReader(csvfile)
    for row in reader:
        publish_date_str = row['publish_date']
        
        # Parse the date string into a datetime object
        publish_date = datetime.strptime(publish_date_str, '%Y-%m-%dT%H:%M:%S%z')
        
        # Extract the month information
        month_of_publish = publish_date.strftime('%Y-%m')
        
        collection.append({'month': month_of_publish, 'headline': row['headline']})

# Create a frequency time series plot by month
month_counts = Counter(article['month'] for article in collection)
months, counts = zip(*sorted(month_counts.items()))

plt.figure(figsize=(10, 6))
plt.bar(months, counts, color='blue', alpha=0.7)
plt.title('Frequency Time Series Bar Plot by Month')
plt.xlabel('Month')
plt.ylabel('Frequency')

# plt.xticks(rotation=45)

# plt.tight_layout()
plt.show()

# %%
import csv
from datetime import datetime
from collections import Counter
import matplotlib.pyplot as plt

# Read data from CSV file
csv_file_path = 'nyt_headlines.csv'
fieldnames = ['publish_date', 'headline']
collection = []

with open(csv_file_path, 'r', encoding='utf-8') as csvfile:
    reader = csv.DictReader(csvfile)
    for row in reader:
        publish_date_str = row['publish_date']
        
        # Parse the date string into a datetime object
        publish_date = datetime.strptime(publish_date_str, '%Y-%m-%dT%H:%M:%S%z')
        
        # Extract the year information
        year_of_publish = publish_date.strftime('%Y')
        
        collection.append({'year': year_of_publish, 'headline': row['headline']})

# Create a frequency time series bar plot by year
year_counts = Counter(article['year'] for article in collection)
years, counts = zip(*sorted(year_counts.items()))

plt.figure(figsize=(10, 6))
plt.bar(years, counts, color='blue', alpha=0.7)
plt.title('Frequency Time Series Bar Plot by Year')
plt.xlabel('Year')
plt.ylabel('Frequency')

plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
import csv
from datetime import datetime
from collections import Counter
import matplotlib.pyplot as plt

# Read data from CSV file
csv_file_path = 'nyt_headlines.csv'
fieldnames = ['publish_date', 'headline']
collection = []

with open(csv_file_path, 'r', encoding='utf-8') as csvfile:
    reader = csv.DictReader(csvfile)
    for row in reader:
        publish_date_str = row['publish_date']
        
        # Parse the date string into a datetime object
        publish_date = datetime.strptime(publish_date_str, '%Y-%m-%dT%H:%M:%S%z')
        
        # Extract the year information
        year_of_publish = publish_date.strftime('%Y')
        
        collection.append({'year': year_of_publish, 'headline': row['headline']})

# Create a frequency time series line plot by year
year_counts = Counter(article['year'] for article in collection)
years, counts = zip(*sorted(year_counts.items()))

plt.figure(figsize=(10, 6))
plt.plot(years, counts, marker='o', color='blue', linestyle='-', linewidth=2)
plt.title('Frequency Time Series Line Plot by Year')
plt.xlabel('Year')
plt.ylabel('Frequency')

plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
import csv
from datetime import datetime
from collections import Counter
import matplotlib.pyplot as plt

# Read data from CSV file
csv_file_path = 'nyt_headlines.csv'
fieldnames = ['publish_date', 'headline']
collection = []

with open(csv_file_path, 'r', encoding='utf-8') as csvfile:
    reader = csv.DictReader(csvfile)
    for row in reader:
        publish_date_str = row['publish_date']
        
        # Parse the date string into a datetime object
        publish_date = datetime.strptime(publish_date_str, '%Y-%m-%dT%H:%M:%S%z')
        
        # Extract the month information
        month_of_publish = publish_date.strftime('%Y-%m')
        
        collection.append({'month': month_of_publish, 'headline': row['headline']})

# Create a frequency time series line plot by month
month_counts = Counter(article['month'] for article in collection)
months, counts = zip(*sorted(month_counts.items()))

plt.figure(figsize=(10, 6))
plt.plot(months, counts, marker='o', color='blue', linestyle='-', linewidth=2)
plt.title('Frequency Time Series Line Plot by Month')
plt.xlabel('Month')
plt.ylabel('Frequency')

plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
